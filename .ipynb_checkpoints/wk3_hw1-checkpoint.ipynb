# %%
# Python 101: Homework
## By Evelyn J. Boettcher
## Week 3 Lesson 1: Linear Regression

### Problem 1
# * Explain what np.polynomial does in this script.
##ANS: it takes the x-data, y-data, and fits it according to a first order polynomial.  The output can be unpacked
#####  into slope and intercept variables.
# ** And what are my options besides Polynomial
##ANS: You could use Scikit learn or another package to conduct a linear regression.
# Out:
# 1.804760549530976 - 3237.55695825789 x**1

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

df = pd.read_csv('co2_weekly_mlo.txt', skiprows=49,
                     names=['yr', 'mon', 'day', 'decimal', 'ppm', ' #days', '1 yr ago', '10 yr ago', 'since 1800'],
                     delim_whitespace=True)
clean_df = df[df.ppm != -999.99]
clean_df.head()
pp = np.polynomial.Polynomial(np.polyfit(clean_df.decimal, clean_df.ppm, 1))
print(pp)
plt.scatter(clean_df.decimal, clean_df.ppm)
plt.show()
plt.plot(clean_df.decimal, clean_df.decimal*slope+intercept, color='red', label= 'Fit')
plt.show()
plt.plot(clean_df.decimal, pp(clean_df), color='red')
plt.show()

# %%
clean_df
# Out:
#         yr  mon  day    decimal     ppm   #days  1 yr ago  10 yr ago  \
# 0     1974    5   19  1974.3795  333.37       5   -999.99    -999.99
# 1     1974    5   26  1974.3986  332.95       6   -999.99    -999.99
# 2     1974    6    2  1974.4178  332.35       5   -999.99    -999.99
# 3     1974    6    9  1974.4370  332.20       7   -999.99    -999.99
# 4     1974    6   16  1974.4562  332.37       7   -999.99    -999.99
# ...    ...  ...  ...        ...     ...     ...       ...        ...
# 2461  2021    7   18  2021.5438  416.74       7    414.15     391.57
# 2462  2021    7   25  2021.5630  415.62       6    413.55     392.21
# 2463  2021    8    1  2021.5822  415.00       7    413.52     391.21
# 2464  2021    8    8  2021.6014  414.55       5    413.03     390.70
# 2465  2021    8   15  2021.6205  414.91       7    412.61     390.33
#
#       since 1800
# 0          50.40
# 1          50.06
# 2          49.60
# 3          49.65
# 4          50.06
# ...          ...
# 2461      136.81
# 2462      136.23
# 2463      136.13
# 2464      136.20
# 2465      137.06
#
# [2448 rows x 9 columns]

# %%
### Problem 2
clean_df.plot('decimal','ppm')
plt.show()

print(pp)
# Out:
# 1.804760549530976 - 3237.55695825789 x**1

# %%
### Problem 3

# - [ ] What happens if you try to run this

import scipy as sp

sp.stats.linregress(clean_df.decimal, clean_df.ppm)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_17364/2451213355.py in <module>
#       5 import scipy as sp
#       6
# ----> 7 sp.stats.linregress(clean_df.decimal, clean_df.ppm)
#       8
#
# AttributeError: module 'scipy' has no attribute 'stats'

# %%
### Problem 4

#- [ ] For the Seaborn example
#   - [ ] Change the order to: 2 or 3


import seaborn as sns; sns.set_theme(color_codes=True)
import pandas as pd
import matplotlib.pyplot as plt

# Get Data
df = pd.read_csv('co2_weekly_mlo.txt', skiprows=49,
                 names=['yr', 'mon', 'day', 'decimal','ppm', '#days', '1 yr ago', '10 yr ago', 'since 1800'],
                 delim_whitespace=True)
clean_df = df[df.ppm != -999.99]
# Set the plots
ax = sns.regplot(x='decimal', y='ppm', data=clean_df, ci=95, order=1,
                 line_kws={'label': 'Linear regression line: $Y(X)=-3827 + 1.8 X$', 'color': 'm'},
                 label="CO2 Weekly average")
ax.set_ylabel("CO2 (ppm)")
ax.set_xlabel("Year")
ax.legend(loc="upper left")
plt.show()


### Problem 5 (a,b)
#   - [ ] Add x_bins = 100
#   - [ ] Add x_bins = 50
